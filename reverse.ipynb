# %%
def reverse_string(test_string):
    return test_string[::-1]

if __name__ == "__main__":
    test_string = "Hello, World!"

    print(f"Original string: {test_string}")
    print(f"Reversed string: {reverse_string(test_string)}")

    test_cases = ["", "abc", "racecar", "123456789", "cat in the hat"]

    for test in test_cases:
        print(f"'{test}' reversed is '{reverse_string(test)}'")
# Out:
# Original string: Hello, World!
# Reversed string: !dlroW ,olleH
# '' reversed is ''
# 'abc' reversed is 'cba'
# 'racecar' reversed is 'racecar'
# '123456789' reversed is '987654321'
# 'cat in the hat' reversed is 'tah eht ni tac'
